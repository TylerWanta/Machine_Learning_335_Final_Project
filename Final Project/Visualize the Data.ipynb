# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data_part1.csv', index_col=0)

# %%
#  *hashtag nice*
data
# Out:
#           id gender  season  age  tripletsOfMonths  commonRed  commonGreen  \
# 0      15970    Men    Fall    2                 4        254          254
# 1      39386    Men  Summer    2                 3         40           53
# 2      59263  Women  Winter    2                 1        234          234
# 3      21379    Men    Fall    2                 4         50           50
# 4      53759    Men  Summer    2                 3          0            0
# ...      ...    ...     ...  ...               ...        ...          ...
# 44441  17036    Men  Summer    2                 3        241          242
# 44442   6461    Men  Summer    2                 3        223          220
# 44443  18842    Men    Fall    2                 4        144          191
# 44444  46694  Women  Spring    2                 2        253          253
# 44445  51623  Women  Winter    2                 1        216          216
#
#        commonBlue
# 0              90
# 1              59
# 2             234
# 3              52
# 4               0
# ...           ...
# 44441         234
# 44442         213
# 44443         221
# 44444         253
# 44445         225
#
# [44446 rows x 8 columns]

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data[['age', 'tripletsOfMonths', 'commonRed', 'commonGreen', 'commonBlue']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000012735C76248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012735E1A088>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012735E3D488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012735E72E88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012735EAD888>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000012735EE7288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012735F1BF88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000127388A9108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000127388B0CC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000127388E7E88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000012738953448>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001273898C4C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000127389C45C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000127389FC708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012738A36808>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000012738A6E908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012738AA89C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012738AE1AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012738B18BC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012738B51D08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000012738B8AE08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012738BC4EC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012738C01048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012738C39188>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012738C71288>]],
#       dtype=object)
